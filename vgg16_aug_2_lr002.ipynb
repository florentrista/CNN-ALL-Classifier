# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
tf.config.list_physical_devices('GPU')
tf.test.is_gpu_available()
# Out:
# WARNING:tensorflow:From C:\Users\LEGION\AppData\Local\Temp\ipykernel_5576\4051749838.py:2: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# True

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
import tensorflow as tf
from zipfile import ZipFile
import os,glob
import cv2
from tqdm.notebook import tqdm_notebook as tqdm
import numpy as np
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Convolution2D, Dropout, Dense,MaxPooling2D
from keras.layers import BatchNormalization
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from zipfile import ZipFile
import numpy as np
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import pandas as pd
from keras.callbacks import ModelCheckpoint

# %%
import sys
from PIL import Image
sys.modules['Image'] = Image

# %%
from PIL import Image
print(Image.__file__)
# Out:
# c:\Users\LEGION\anaconda3\envs\python310\lib\site-packages\PIL\Image.py

# %%
import Image
print(Image.__file__)
# Out:
# c:\Users\LEGION\anaconda3\envs\python310\lib\site-packages\PIL\Image.py

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# scale_datagen = ImageDataGenerator(rescale=1./255,
#                                    validation_split=0.3)

scale_datagen = ImageDataGenerator(rescale=1./255)

# %%
# train_dir = r"D:\PROJECT\2_COMPUTER VISION\Image Segmentation\Augmented"
# # train_dir = '/content/drive/MyDrive/Colab Skripsi/DATASETNEW/2_Augmented'
# # val_dir = '/content/drive/MyDrive/Colab Skripsi/DATASETNEW/2_Split/val'
# # test_dir = '/content/drive/MyDrive/Colab Skripsi/DATASETNEW/2_Split/test'


train_dir = r"D:\PROJECT\2_COMPUTER VISION\Image Segmentation\SPLIT_TRAINDATA\train"
val_dir = r"D:\PROJECT\2_COMPUTER VISION\Image Segmentation\SPLIT_TRAINDATA\val"
test_dir = r"D:\PROJECT\2_COMPUTER VISION\Image Segmentation\SPLIT_TRAINDATA\test"

# %%
train_generator = scale_datagen.flow_from_directory(
    train_dir,
    # subset='training',
    target_size=(224, 224),
    batch_size=40,
    class_mode='categorical'
)
# Out:
# Found 20422 images belonging to 4 classes.

# %%
val_generator = scale_datagen.flow_from_directory(
    val_dir,
    # subset='validation',
    target_size=(224, 224),
    batch_size=40,
    class_mode='categorical'
)
# Out:
# Found 5834 images belonging to 4 classes.

# %%
test_generator = scale_datagen.flow_from_directory(
    test_dir,
    # subset='validation',
    target_size=(224, 224),
    batch_size=40,
    class_mode='categorical'
)
# Out:
# Found 2922 images belonging to 4 classes.

# %%
print(len(train_generator))
print(len(val_generator))
print(len(test_generator))
# Out:
# 511
# 146
# 74

# %%
# jadi ini modelnya kek gausah bikin dari nol lagi tapi pake arsitektur yang udah ada

from keras.applications import vgg16
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten, GlobalAveragePooling2D
from keras.layers import Conv2D, MaxPooling2D, ZeroPadding2D

from keras.models import Model

# SET DIMENSI INPUTNYA
img_rows, img_cols = 224, 224

# model learningnya based on imagenet dataset jadi weightnya set ke imagenet
# top layer diganti soalnya outputnya ada 20k neuron, tapi kita cuma butuh 2 neuron soalnya outputnya kan cuma 2, yes sama no
# ini download model yang udah ada jadi pake model vgg16
vgg = vgg16.VGG16(weights = "imagenet",
                  include_top = False,
                  input_shape = (img_rows, img_cols, 3))

# Ngefreeze 4 layer terkahir
# Layers yang di set ke trainable defaultnya True

for layer in vgg.layers:
  layer.trainable = False

# ngeprint semua layernya
for (i, layer) in enumerate(vgg.layers):
  print(str(i) + " "+ layer.__class__.__name__, layer.trainable)
# Out:
# 0 InputLayer False
# 1 Conv2D False
# 2 Conv2D False
# 3 MaxPooling2D False
# 4 Conv2D False
# 5 Conv2D False
# 6 MaxPooling2D False
# 7 Conv2D False
# 8 Conv2D False
# 9 Conv2D False
# 10 MaxPooling2D False
# 11 Conv2D False
# 12 Conv2D False
# 13 Conv2D False
# 14 MaxPooling2D False
# 15 Conv2D False
# 16 Conv2D False
# 17 Conv2D False
# 18 MaxPooling2D False

# %%
# tambahin beberapa layer ke model itu tadi

def lw(bottom_model, num_classes):
  """"creates the top or head of the model that will be
  placed ontop of the bottom layers"""

  top_model = bottom_model.output
  top_model = GlobalAveragePooling2D()(top_model)
  top_model = Dense(1024,activation="relu")(top_model)
  top_model = Dense(1024,activation="relu")(top_model)
  top_model = Dense(512,activation="relu")(top_model)
  top_model = Dense(num_classes,activation='softmax')(top_model) #last output layer, number of classes = 4
  return top_model

# %%
# itu tadi udah dibikin function lw nya, secara function lwnya di call

# jumlah class nya 2 soalnya yes sama no
num_classes = 4

FC_Head = lw(vgg, num_classes)

model = Model(inputs = vgg.input, outputs = FC_Head)

print(model.summary())
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 1024)              525312
#
#  dense_1 (Dense)             (None, 1024)              1049600
#
#  dense_2 (Dense)             (None, 512)               524800
#
#  dense_3 (Dense)             (None, 4)                 2052
#
# =================================================================
# Total params: 16,816,452
# Trainable params: 2,101,764
# Non-trainable params: 14,714,688
# _________________________________________________________________
# None

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
# model.compile(optimizer='adam', loss = 'categorical_crossentropy',metrics = ['accuracy'])


learning_rate = 0.002
optimizer = Adam(learning_rate=learning_rate)

model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# training mulai
filepath=r'D:\PROJECT\SKRIPSI\skripsi_vgg16_002_augment_1.model.keras'
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_accuracy',
                             save_best_only=True,
                             mode='max',
                             verbose=1)
history = model.fit(train_generator,
                    epochs=20,
                    validation_data=(val_generator),
                    initial_epoch=0,
                    callbacks=[checkpoint])


# # training mulai

# history = model.fit(train_generator,
#                     epochs=10,
#                     validation_data=(val_generator),
#                     verbose = 1,
#                     initial_epoch=0)
# Out:
# Epoch 1/20
# 511/511 [==============================] - ETA: 0s - loss: 0.5156 - accuracy: 0.7941
# Epoch 1: val_accuracy improved from -inf to 0.87624, saving model to D:\PROJECT\SKRIPSI\skripsi_vgg16_002_augment_1.model.keras
# 511/511 [==============================] - 389s 739ms/step - loss: 0.5156 - accuracy: 0.7941 - val_loss: 0.3202 - val_accuracy: 0.8762
# Epoch 2/20
# 511/511 [==============================] - ETA: 0s - loss: 0.3148 - accuracy: 0.8792
# Epoch 2: val_accuracy did not improve from 0.87624
# 511/511 [==============================] - 174s 340ms/step - loss: 0.3148 - accuracy: 0.8792 - val_loss: 0.3542 - val_accuracy: 0.8574
# Epoch 3/20
# 511/511 [==============================] - ETA: 0s - loss: 0.2712 - accuracy: 0.8957
# Epoch 3: val_accuracy improved from 0.87624 to 0.90213, saving model to D:\PROJECT\SKRIPSI\skripsi_vgg16_002_augment_1.model.keras
# 511/511 [==============================] - 175s 342ms/step - loss: 0.2712 - accuracy: 0.8957 - val_loss: 0.2500 - val_accuracy: 0.9021
# Epoch 4/20
# 511/511 [==============================] - ETA: 0s - loss: 0.2484 - accuracy: 0.9051
# Epoch 4: val_accuracy improved from 0.90213 to 0.91190, saving model to D:\PROJECT\SKRIPSI\skripsi_vgg16_002_augment_1.model.keras
# 511/511 [==============================] - 179s 350ms/step - loss: 0.2484 - accuracy: 0.9051 - val_loss: 0.2242 - val_accuracy: 0.9119
# Epoch 5/20
# 511/511 [==============================] - ETA: 0s - loss: 0.2277 - accuracy: 0.9132
# Epoch 5: val_accuracy did not improve from 0.91190
# 511/511 [==============================] - 176s 345ms/step - loss: 0.2277 - accuracy: 0.9132 - val_loss: 0.2940 - val_accuracy: 0.8857
# Epoch 6/20
# 511/511 [==============================] - ETA: 0s - loss: 0.2086 - accuracy: 0.9204
# Epoch 6: val_accuracy did not improve from 0.91190
# 511/511 [==============================] - 172s 336ms/step - loss: 0.2086 - accuracy: 0.9204 - val_loss: 0.2349 - val_accuracy: 0.9052
# Epoch 7/20
# 511/511 [==============================] - ETA: 0s - loss: 0.1988 - accuracy: 0.9229
# Epoch 7: val_accuracy improved from 0.91190 to 0.91635, saving model to D:\PROJECT\SKRIPSI\skripsi_vgg16_002_augment_1.model.keras
# 511/511 [==============================] - 172s 336ms/step - loss: 0.1988 - accuracy: 0.9229 - val_loss: 0.2192 - val_accuracy: 0.9164
# Epoch 8/20
# 511/511 [==============================] - ETA: 0s - loss: 0.1843 - accuracy: 0.9304
# Epoch 8: val_accuracy improved from 0.91635 to 0.92869, saving model to D:\PROJECT\SKRIPSI\skripsi_vgg16_002_augment_1.model.keras
# 511/511 [==============================] - 172s 336ms/step - loss: 0.1843 - accuracy: 0.9304 - val_loss: 0.1848 - val_accuracy: 0.9287
# Epoch 9/20
# 511/511 [==============================] - ETA: 0s - loss: 0.1852 - accuracy: 0.9300
# Epoch 9: val_accuracy did not improve from 0.92869
# 511/511 [==============================] - 172s 337ms/step - loss: 0.1852 - accuracy: 0.9300 - val_loss: 0.1922 - val_accuracy: 0.9212
# Epoch 10/20
# 511/511 [==============================] - ETA: 0s - loss: 0.1701 - accuracy: 0.9358
# Epoch 10: val_accuracy improved from 0.92869 to 0.93298, saving model to D:\PROJECT\SKRIPSI\skripsi_vgg16_002_augment_1.model.keras
# 511/511 [==============================] - 174s 341ms/step - loss: 0.1701 - accuracy: 0.9358 - val_loss: 0.1752 - val_accuracy: 0.9330
# Epoch 11/20
# 511/511 [==============================] - ETA: 0s - loss: 0.1605 - accuracy: 0.9387
# Epoch 11: val_accuracy improved from 0.93298 to 0.93521, saving model to D:\PROJECT\SKRIPSI\skripsi_vgg16_002_augment_1.model.keras
# 511/511 [==============================] - 179s 350ms/step - loss: 0.1605 - accuracy: 0.9387 - val_loss: 0.1613 - val_accuracy: 0.9352
# Epoch 12/20
# 511/511 [==============================] - ETA: 0s - loss: 0.1581 - accuracy: 0.9404
# Epoch 12: val_accuracy did not improve from 0.93521
# 511/511 [==============================] - 184s 360ms/step - loss: 0.1581 - accuracy: 0.9404 - val_loss: 0.1762 - val_accuracy: 0.9326
# Epoch 13/20
# 511/511 [==============================] - ETA: 0s - loss: 0.1545 - accuracy: 0.9394
# Epoch 13: val_accuracy did not improve from 0.93521
# 511/511 [==============================] - 185s 362ms/step - loss: 0.1545 - accuracy: 0.9394 - val_loss: 0.1802 - val_accuracy: 0.9273
# Epoch 14/20
# 511/511 [==============================] - ETA: 0s - loss: 0.1447 - accuracy: 0.9445
# Epoch 14: val_accuracy improved from 0.93521 to 0.94069, saving model to D:\PROJECT\SKRIPSI\skripsi_vgg16_002_augment_1.model.keras
# 511/511 [==============================] - 186s 364ms/step - loss: 0.1447 - accuracy: 0.9445 - val_loss: 0.1544 - val_accuracy: 0.9407
# Epoch 15/20
# 511/511 [==============================] - ETA: 0s - loss: 0.1475 - accuracy: 0.9447
# Epoch 15: val_accuracy did not improve from 0.94069
# 511/511 [==============================] - 185s 362ms/step - loss: 0.1475 - accuracy: 0.9447 - val_loss: 0.1863 - val_accuracy: 0.9272
# Epoch 16/20
# 511/511 [==============================] - ETA: 0s - loss: 0.1461 - accuracy: 0.9460
# Epoch 16: val_accuracy improved from 0.94069 to 0.94652, saving model to D:\PROJECT\SKRIPSI\skripsi_vgg16_002_augment_1.model.keras
# 511/511 [==============================] - 185s 362ms/step - loss: 0.1461 - accuracy: 0.9460 - val_loss: 0.1425 - val_accuracy: 0.9465
# Epoch 17/20
# 511/511 [==============================] - ETA: 0s - loss: 0.1357 - accuracy: 0.9479
# Epoch 17: val_accuracy did not improve from 0.94652
# 511/511 [==============================] - 187s 365ms/step - loss: 0.1357 - accuracy: 0.9479 - val_loss: 0.1495 - val_accuracy: 0.9407
# Epoch 18/20
# 511/511 [==============================] - ETA: 0s - loss: 0.1343 - accuracy: 0.9482
# Epoch 18: val_accuracy did not improve from 0.94652
# 511/511 [==============================] - 186s 363ms/step - loss: 0.1343 - accuracy: 0.9482 - val_loss: 0.1389 - val_accuracy: 0.9446
# Epoch 19/20
# 511/511 [==============================] - ETA: 0s - loss: 0.1286 - accuracy: 0.9515
# Epoch 19: val_accuracy did not improve from 0.94652
# 511/511 [==============================] - 185s 361ms/step - loss: 0.1286 - accuracy: 0.9515 - val_loss: 0.1392 - val_accuracy: 0.9460
# Epoch 20/20
# 511/511 [==============================] - ETA: 0s - loss: 0.1298 - accuracy: 0.9507
# Epoch 20: val_accuracy did not improve from 0.94652
# 511/511 [==============================] - 175s 343ms/step - loss: 0.1298 - accuracy: 0.9507 - val_loss: 0.1552 - val_accuracy: 0.9409

# %%
# SAVE MODEL
save_path = r"D:\PROJECT\SKRIPSI\skripsi_vgg16_002_augment_1.h5"
model.save(save_path)

# %%
# SAVE MODEL
weights_path = r"D:\PROJECT\SKRIPSI\skripsi_vgg16_002_augment_1_weights.h5"
model.save_weights(weights_path)

# %% [markdown]
# EVALUASI

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='validation accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc=0)
plt.figure()

plt.show()

# %%
# Grafik plot value accuracy training sama validation
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(acc, 'r', label='Training Accuracy')
plt.plot(val_acc, 'b', label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# Grafik plot value loss training sama validation
plt.subplot(1, 2, 2)
plt.plot(loss, 'g', label='Training Loss')
plt.plot(val_loss, 'y', label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.show()

# %%
from tensorflow import keras

model = keras.models.load_model("skripsi_vgg16_002_augment_1.model.keras")

# %%
test_dir = r"D:\PROJECT\2_COMPUTER VISION\Image Segmentation\SPLIT_TRAINDATA\test"

# %%
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator

img_size = (224, 224)
batch_size = 40

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode="categorical",  # Change to 'categorical' if multi-class
    shuffle=False
)

true_labels = test_generator.classes
# Out:
# Found 2922 images belonging to 4 classes.

# %%
pred_probs = model.predict(test_generator)

pred_labels = np.argmax(pred_probs, axis=1)
# Out:
# 74/74 [==============================] - 22s 295ms/step

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(true_labels, pred_labels)

print("Confusion Matrix:")
print(cm)
# Out:
# Confusion Matrix:
# [[835  11   1  35]
#  [ 27 822   2   9]
#  [  6   4 703   5]
#  [ 29   4   0 429]]

# %%
from sklearn.metrics import classification_report, accuracy_score

class_labels = list(test_generator.class_indices.keys())
print("Classification Report:")
print(classification_report(true_labels, pred_labels, target_names=class_labels, digits=4))

# akurasi
accuracy = accuracy_score(true_labels, pred_labels)
print(f"Accuracy: {accuracy:.4f}")
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#    EarlyPreB     0.9309    0.9467    0.9387       882
#         PreB     0.9774    0.9558    0.9665       860
#         ProB     0.9958    0.9791    0.9874       718
#       benign     0.8975    0.9286    0.9128       462
#
#     accuracy                         0.9545      2922
#    macro avg     0.9504    0.9526    0.9513      2922
# weighted avg     0.9552    0.9545    0.9547      2922
#
# Accuracy: 0.9545

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()
