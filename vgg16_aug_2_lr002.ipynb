# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
tf.config.list_physical_devices('GPU')
tf.test.is_gpu_available()
# Out:
# WARNING:tensorflow:From C:\Users\LEGION\AppData\Local\Temp\ipykernel_17852\4051749838.py:2: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# True

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
import tensorflow as tf
from zipfile import ZipFile
import os,glob
import cv2
from tqdm.notebook import tqdm_notebook as tqdm
import numpy as np
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Convolution2D, Dropout, Dense,MaxPooling2D
from keras.layers import BatchNormalization
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from zipfile import ZipFile
import numpy as np
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import pandas as pd
from keras.callbacks import ModelCheckpoint

# %%
import sys
from PIL import Image
sys.modules['Image'] = Image

# %%
from PIL import Image
print(Image.__file__)
# Out:
# c:\Users\LEGION\anaconda3\envs\python310\lib\site-packages\PIL\Image.py

# %%
import Image
print(Image.__file__)
# Out:
# c:\Users\LEGION\anaconda3\envs\python310\lib\site-packages\PIL\Image.py

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# scale_datagen = ImageDataGenerator(rescale=1./255,
#                                    validation_split=0.3)

scale_datagen = ImageDataGenerator(rescale=1./255)

# %%
# train_dir = r"D:\PROJECT\2_COMPUTER VISION\Image Segmentation\Augmented"
# # train_dir = '/content/drive/MyDrive/Colab Skripsi/DATASETNEW/2_Augmented'
# # val_dir = '/content/drive/MyDrive/Colab Skripsi/DATASETNEW/2_Split/val'
# # test_dir = '/content/drive/MyDrive/Colab Skripsi/DATASETNEW/2_Split/test'


train_dir = r"D:\PROJECT\2_COMPUTER VISION\Image Segmentation\Data Train Gabungan"
val_dir = r"D:\PROJECT\2_COMPUTER VISION\Image Segmentation\Data Val Gabungan"
test_dir = r"D:\PROJECT\2_COMPUTER VISION\Image Segmentation\SPLIT\test"

# %%
train_generator = scale_datagen.flow_from_directory(
    train_dir,
    # subset='training',
    target_size=(224, 224),
    batch_size=40,
    class_mode='categorical'
)
# Out:
# Found 20412 images belonging to 4 classes.

# %%
val_generator = scale_datagen.flow_from_directory(
    val_dir,
    # subset='validation',
    target_size=(224, 224),
    batch_size=40,
    class_mode='categorical'
)
# Out:
# Found 5823 images belonging to 4 classes.

# %%
test_generator = scale_datagen.flow_from_directory(
    test_dir,
    # subset='validation',
    target_size=(224, 224),
    batch_size=40,
    class_mode='categorical'
)
# Out:
# Found 327 images belonging to 4 classes.

# %%
print(len(train_generator))
print(len(val_generator))
print(len(test_generator))
# Out:
# 511
# 146
# 9

# %%
# jadi ini modelnya kek gausah bikin dari nol lagi tapi pake arsitektur yang udah ada

from keras.applications import vgg16
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten, GlobalAveragePooling2D
from keras.layers import Conv2D, MaxPooling2D, ZeroPadding2D

from keras.models import Model

# SET DIMENSI INPUTNYA
img_rows, img_cols = 224, 224

# model learningnya based on imagenet dataset jadi weightnya set ke imagenet
# top layer diganti soalnya outputnya ada 20k neuron, tapi kita cuma butuh 2 neuron soalnya outputnya kan cuma 2, yes sama no
# ini download model yang udah ada jadi pake model vgg16
vgg = vgg16.VGG16(weights = "imagenet",
                  include_top = False,
                  input_shape = (img_rows, img_cols, 3))

# Ngefreeze 4 layer terkahir
# Layers yang di set ke trainable defaultnya True

for layer in vgg.layers:
  layer.trainable = False

# ngeprint semua layernya
for (i, layer) in enumerate(vgg.layers):
  print(str(i) + " "+ layer.__class__.__name__, layer.trainable)
# Out:
# 0 InputLayer False
# 1 Conv2D False
# 2 Conv2D False
# 3 MaxPooling2D False
# 4 Conv2D False
# 5 Conv2D False
# 6 MaxPooling2D False
# 7 Conv2D False
# 8 Conv2D False
# 9 Conv2D False
# 10 MaxPooling2D False
# 11 Conv2D False
# 12 Conv2D False
# 13 Conv2D False
# 14 MaxPooling2D False
# 15 Conv2D False
# 16 Conv2D False
# 17 Conv2D False
# 18 MaxPooling2D False

# %%
# tambahin beberapa layer ke model itu tadi

def lw(bottom_model, num_classes):
  """"creates the top or head of the model that will be
  placed ontop of the bottom layers"""

  top_model = bottom_model.output
  top_model = GlobalAveragePooling2D()(top_model)
  top_model = Dense(1024,activation="relu")(top_model)
  top_model = Dense(1024,activation="relu")(top_model)
  top_model = Dense(512,activation="relu")(top_model)
  top_model = Dense(num_classes,activation='softmax')(top_model) #last output layer, number of classes = 4
  return top_model

# %%
# itu tadi udah dibikin function lw nya, secara function lwnya di call

# jumlah class nya 2 soalnya yes sama no
num_classes = 4

FC_Head = lw(vgg, num_classes)

model = Model(inputs = vgg.input, outputs = FC_Head)

print(model.summary())
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 1024)              525312
#
#  dense_1 (Dense)             (None, 1024)              1049600
#
#  dense_2 (Dense)             (None, 512)               524800
#
#  dense_3 (Dense)             (None, 4)                 2052
#
# =================================================================
# Total params: 16,816,452
# Trainable params: 2,101,764
# Non-trainable params: 14,714,688
# _________________________________________________________________
# None

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
# model.compile(optimizer='adam', loss = 'categorical_crossentropy',metrics = ['accuracy'])


learning_rate = 0.002
optimizer = Adam(learning_rate=learning_rate)

model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# training mulai
filepath=r'D:\PROJECT\SKRIPSI\skripsi_vgg16_002_augment_1.model.keras'
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_accuracy',
                             save_best_only=True,
                             mode='max',
                             verbose=1)
history = model.fit(train_generator,
                    epochs=30,
                    validation_data=(val_generator),
                    initial_epoch=0,
                    callbacks=[checkpoint])


# # training mulai

# history = model.fit(train_generator,
#                     epochs=10,
#                     validation_data=(val_generator),
#                     verbose = 1,
#                     initial_epoch=0)
# Out:
# Epoch 1/30
# 511/511 [==============================] - ETA: 0s - loss: 0.5233 - accuracy: 0.7931
# Epoch 1: val_accuracy improved from -inf to 0.86158, saving model to D:\PROJECT\SKRIPSI\skripsi_vgg16_002_augment_1.model.keras
# 511/511 [==============================] - 180s 336ms/step - loss: 0.5233 - accuracy: 0.7931 - val_loss: 0.3539 - val_accuracy: 0.8616
# Epoch 2/30
# 511/511 [==============================] - ETA: 0s - loss: 0.3058 - accuracy: 0.8803
# Epoch 2: val_accuracy improved from 0.86158 to 0.87120, saving model to D:\PROJECT\SKRIPSI\skripsi_vgg16_002_augment_1.model.keras
# 511/511 [==============================] - 167s 326ms/step - loss: 0.3058 - accuracy: 0.8803 - val_loss: 0.3703 - val_accuracy: 0.8712
# Epoch 3/30
# 511/511 [==============================] - ETA: 0s - loss: 0.2835 - accuracy: 0.8885
# Epoch 3: val_accuracy improved from 0.87120 to 0.90898, saving model to D:\PROJECT\SKRIPSI\skripsi_vgg16_002_augment_1.model.keras
# 511/511 [==============================] - 167s 326ms/step - loss: 0.2835 - accuracy: 0.8885 - val_loss: 0.2435 - val_accuracy: 0.9090
# Epoch 4/30
# 511/511 [==============================] - ETA: 0s - loss: 0.2557 - accuracy: 0.8994
# Epoch 4: val_accuracy did not improve from 0.90898
# 511/511 [==============================] - 166s 325ms/step - loss: 0.2557 - accuracy: 0.8994 - val_loss: 0.2615 - val_accuracy: 0.9006
# Epoch 5/30
# 511/511 [==============================] - ETA: 0s - loss: 0.2168 - accuracy: 0.9126
# Epoch 5: val_accuracy did not improve from 0.90898
# 511/511 [==============================] - 164s 322ms/step - loss: 0.2168 - accuracy: 0.9126 - val_loss: 0.2463 - val_accuracy: 0.9035
# Epoch 6/30
# 511/511 [==============================] - ETA: 0s - loss: 0.2111 - accuracy: 0.9181
# Epoch 6: val_accuracy did not improve from 0.90898
# 511/511 [==============================] - 164s 321ms/step - loss: 0.2111 - accuracy: 0.9181 - val_loss: 0.3534 - val_accuracy: 0.8796
# Epoch 7/30
# 511/511 [==============================] - ETA: 0s - loss: 0.1915 - accuracy: 0.9243
# Epoch 7: val_accuracy improved from 0.90898 to 0.91104, saving model to D:\PROJECT\SKRIPSI\skripsi_vgg16_002_augment_1.model.keras
# 511/511 [==============================] - 164s 322ms/step - loss: 0.1915 - accuracy: 0.9243 - val_loss: 0.2765 - val_accuracy: 0.9110
# Epoch 8/30
# 511/511 [==============================] - ETA: 0s - loss: 0.1881 - accuracy: 0.9283
# Epoch 8: val_accuracy improved from 0.91104 to 0.92358, saving model to D:\PROJECT\SKRIPSI\skripsi_vgg16_002_augment_1.model.keras
# 511/511 [==============================] - 167s 327ms/step - loss: 0.1881 - accuracy: 0.9283 - val_loss: 0.2105 - val_accuracy: 0.9236
# Epoch 9/30
# 511/511 [==============================] - ETA: 0s - loss: 0.1741 - accuracy: 0.9321
# Epoch 9: val_accuracy did not improve from 0.92358
# 511/511 [==============================] - 169s 330ms/step - loss: 0.1741 - accuracy: 0.9321 - val_loss: 0.2256 - val_accuracy: 0.9179
# Epoch 10/30
# 511/511 [==============================] - ETA: 0s - loss: 0.1710 - accuracy: 0.9344
# Epoch 10: val_accuracy did not improve from 0.92358
# 511/511 [==============================] - 168s 328ms/step - loss: 0.1710 - accuracy: 0.9344 - val_loss: 0.2403 - val_accuracy: 0.9224
# Epoch 11/30
# 511/511 [==============================] - ETA: 0s - loss: 0.1583 - accuracy: 0.9371
# Epoch 11: val_accuracy did not improve from 0.92358
# 511/511 [==============================] - 165s 324ms/step - loss: 0.1583 - accuracy: 0.9371 - val_loss: 0.2192 - val_accuracy: 0.9126
# Epoch 12/30
# 511/511 [==============================] - ETA: 0s - loss: 0.1522 - accuracy: 0.9413
# Epoch 12: val_accuracy did not improve from 0.92358
# 511/511 [==============================] - 165s 324ms/step - loss: 0.1522 - accuracy: 0.9413 - val_loss: 0.2306 - val_accuracy: 0.9212
# Epoch 13/30
# 511/511 [==============================] - ETA: 0s - loss: 0.1544 - accuracy: 0.9388
# Epoch 13: val_accuracy did not improve from 0.92358
# 511/511 [==============================] - 165s 324ms/step - loss: 0.1544 - accuracy: 0.9388 - val_loss: 0.2247 - val_accuracy: 0.9164
# Epoch 14/30
# 511/511 [==============================] - ETA: 0s - loss: 0.1475 - accuracy: 0.9416
# Epoch 14: val_accuracy did not improve from 0.92358
# 511/511 [==============================] - 167s 326ms/step - loss: 0.1475 - accuracy: 0.9416 - val_loss: 0.2532 - val_accuracy: 0.9067
# Epoch 15/30
# 511/511 [==============================] - ETA: 0s - loss: 0.1365 - accuracy: 0.9466
# Epoch 15: val_accuracy improved from 0.92358 to 0.93010, saving model to D:\PROJECT\SKRIPSI\skripsi_vgg16_002_augment_1.model.keras
# 511/511 [==============================] - 167s 326ms/step - loss: 0.1365 - accuracy: 0.9466 - val_loss: 0.2100 - val_accuracy: 0.9301
# Epoch 16/30
# 511/511 [==============================] - ETA: 0s - loss: 0.1235 - accuracy: 0.9503
# Epoch 16: val_accuracy improved from 0.93010 to 0.93749, saving model to D:\PROJECT\SKRIPSI\skripsi_vgg16_002_augment_1.model.keras
# 511/511 [==============================] - 167s 326ms/step - loss: 0.1235 - accuracy: 0.9503 - val_loss: 0.1931 - val_accuracy: 0.9375
# Epoch 17/30
# 511/511 [==============================] - ETA: 0s - loss: 0.1250 - accuracy: 0.9506
# Epoch 17: val_accuracy did not improve from 0.93749
# 511/511 [==============================] - 167s 327ms/step - loss: 0.1250 - accuracy: 0.9506 - val_loss: 0.2144 - val_accuracy: 0.9272
# Epoch 18/30
# 511/511 [==============================] - ETA: 0s - loss: 0.1265 - accuracy: 0.9488
# Epoch 18: val_accuracy did not improve from 0.93749
# 511/511 [==============================] - 168s 329ms/step - loss: 0.1265 - accuracy: 0.9488 - val_loss: 0.1990 - val_accuracy: 0.9332
# Epoch 19/30
# 511/511 [==============================] - ETA: 0s - loss: 0.1182 - accuracy: 0.9541
# Epoch 19: val_accuracy did not improve from 0.93749
# 511/511 [==============================] - 168s 328ms/step - loss: 0.1182 - accuracy: 0.9541 - val_loss: 0.2317 - val_accuracy: 0.9155
# Epoch 20/30
# 511/511 [==============================] - ETA: 0s - loss: 0.1176 - accuracy: 0.9532
# Epoch 20: val_accuracy did not improve from 0.93749
# 511/511 [==============================] - 169s 331ms/step - loss: 0.1176 - accuracy: 0.9532 - val_loss: 0.1982 - val_accuracy: 0.9363
# Epoch 21/30
# 511/511 [==============================] - ETA: 0s - loss: 0.1104 - accuracy: 0.9555
# Epoch 21: val_accuracy did not improve from 0.93749
# 511/511 [==============================] - 169s 332ms/step - loss: 0.1104 - accuracy: 0.9555 - val_loss: 0.2183 - val_accuracy: 0.9353
# Epoch 22/30
# 511/511 [==============================] - ETA: 0s - loss: 0.1130 - accuracy: 0.9570
# Epoch 22: val_accuracy did not improve from 0.93749
# 511/511 [==============================] - 173s 338ms/step - loss: 0.1130 - accuracy: 0.9570 - val_loss: 0.2259 - val_accuracy: 0.9320
# Epoch 23/30
# 511/511 [==============================] - ETA: 0s - loss: 0.1112 - accuracy: 0.9563
# Epoch 23: val_accuracy did not improve from 0.93749
# 511/511 [==============================] - 166s 325ms/step - loss: 0.1112 - accuracy: 0.9563 - val_loss: 0.2378 - val_accuracy: 0.9262
# Epoch 24/30
# 511/511 [==============================] - ETA: 0s - loss: 0.1080 - accuracy: 0.9585
# Epoch 24: val_accuracy did not improve from 0.93749
# 511/511 [==============================] - 164s 322ms/step - loss: 0.1080 - accuracy: 0.9585 - val_loss: 0.2047 - val_accuracy: 0.9337
# Epoch 25/30
# 511/511 [==============================] - ETA: 0s - loss: 0.1018 - accuracy: 0.9593
# Epoch 25: val_accuracy did not improve from 0.93749
# 511/511 [==============================] - 170s 333ms/step - loss: 0.1018 - accuracy: 0.9593 - val_loss: 0.2291 - val_accuracy: 0.9267
# Epoch 26/30
# 511/511 [==============================] - ETA: 0s - loss: 0.1027 - accuracy: 0.9593
# Epoch 26: val_accuracy did not improve from 0.93749
# 511/511 [==============================] - 175s 342ms/step - loss: 0.1027 - accuracy: 0.9593 - val_loss: 0.2195 - val_accuracy: 0.9232
# Epoch 27/30
# 511/511 [==============================] - ETA: 0s - loss: 0.1026 - accuracy: 0.9598
# Epoch 27: val_accuracy did not improve from 0.93749
# 511/511 [==============================] - 174s 341ms/step - loss: 0.1026 - accuracy: 0.9598 - val_loss: 0.2353 - val_accuracy: 0.9332
# Epoch 28/30
# 511/511 [==============================] - ETA: 0s - loss: 0.0902 - accuracy: 0.9652
# Epoch 28: val_accuracy did not improve from 0.93749
# 511/511 [==============================] - 175s 341ms/step - loss: 0.0902 - accuracy: 0.9652 - val_loss: 0.2710 - val_accuracy: 0.9280
# Epoch 29/30
# 511/511 [==============================] - ETA: 0s - loss: 0.0946 - accuracy: 0.9633
# Epoch 29: val_accuracy did not improve from 0.93749
# 511/511 [==============================] - 175s 342ms/step - loss: 0.0946 - accuracy: 0.9633 - val_loss: 0.2450 - val_accuracy: 0.9208
# Epoch 30/30
# 511/511 [==============================] - ETA: 0s - loss: 0.0963 - accuracy: 0.9613
# Epoch 30: val_accuracy did not improve from 0.93749
# 511/511 [==============================] - 174s 341ms/step - loss: 0.0963 - accuracy: 0.9613 - val_loss: 0.2546 - val_accuracy: 0.9292

# %%
# SAVE MODEL
save_path = r"D:\PROJECT\SKRIPSI\skripsi_vgg16_002_augment_1.h5"
model.save(save_path)

# %%
# SAVE MODEL
weights_path = r"D:\PROJECT\SKRIPSI\skripsi_vgg16_002_augment_1_weights.h5"
model.save_weights(weights_path)

# %% [markdown]
# EVALUASI

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='validation accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc=0)
plt.figure()

plt.show()

# %%
# Grafik plot value accuracy training sama validation
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(acc, 'r', label='Training Accuracy')
plt.plot(val_acc, 'b', label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# Grafik plot value loss training sama validation
plt.subplot(1, 2, 2)
plt.plot(loss, 'g', label='Training Loss')
plt.plot(val_loss, 'y', label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.show()

# %%
from tensorflow import keras

model = keras.models.load_model("skripsi_vgg16_002_augment_1.h5")

# %%
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator

img_size = (224, 224)
batch_size = 40

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode="categorical",  # Change to 'categorical' if multi-class
    shuffle=False
)

true_labels = test_generator.classes
# Out:
# Found 327 images belonging to 4 classes.

# %%
pred_probs = model.predict(test_generator)

pred_labels = np.argmax(pred_probs, axis=1)
# Out:
# 9/9 [==============================] - 4s 495ms/step

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(true_labels, pred_labels)

print("Confusion Matrix:")
print(cm)
# Out:
# Confusion Matrix:
# [[97  0  0  2]
#  [ 3 92  0  1]
#  [ 2  1 77  0]
#  [ 5  1  0 46]]

# %%
from sklearn.metrics import classification_report, accuracy_score

class_labels = list(test_generator.class_indices.keys())
print("Classification Report:")
print(classification_report(true_labels, pred_labels, target_names=class_labels, digits=4))

# akurasi
accuracy = accuracy_score(true_labels, pred_labels)
print(f"Accuracy: {accuracy:.4f}")
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#    EarlyPreB     0.9065    0.9798    0.9417        99
#         PreB     0.9787    0.9583    0.9684        96
#         ProB     1.0000    0.9625    0.9809        80
#       benign     0.9388    0.8846    0.9109        52
#
#     accuracy                         0.9541       327
#    macro avg     0.9560    0.9463    0.9505       327
# weighted avg     0.9557    0.9541    0.9542       327
#
# Accuracy: 0.9541

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()
