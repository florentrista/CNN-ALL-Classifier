# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
tf.config.list_physical_devices('GPU')
tf.test.is_gpu_available()
# Out:
# WARNING:tensorflow:From C:\Users\LEGION\AppData\Local\Temp\ipykernel_18428\4051749838.py:2: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# True

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
import tensorflow as tf
from zipfile import ZipFile
import os,glob
import cv2
from tqdm.notebook import tqdm_notebook as tqdm
import numpy as np
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Convolution2D, Dropout, Dense,MaxPooling2D
from keras.layers import BatchNormalization
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from zipfile import ZipFile
import numpy as np
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import pandas as pd
from keras.callbacks import ModelCheckpoint

# %%
import sys
from PIL import Image
sys.modules['Image'] = Image

# %%
from PIL import Image
print(Image.__file__)
# Out:
# c:\Users\LEGION\anaconda3\envs\python310\lib\site-packages\PIL\Image.py

# %%
import Image
print(Image.__file__)
# Out:
# c:\Users\LEGION\anaconda3\envs\python310\lib\site-packages\PIL\Image.py

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# scale_datagen = ImageDataGenerator(rescale=1./255,
#                                    validation_split=0.3)

scale_datagen = ImageDataGenerator(rescale=1./255)

# %%
# train_dir = r"D:\PROJECT\2_COMPUTER VISION\Image Segmentation\Augmented"
# # train_dir = '/content/drive/MyDrive/Colab Skripsi/DATASETNEW/2_Augmented'
# # val_dir = '/content/drive/MyDrive/Colab Skripsi/DATASETNEW/2_Split/val'
# # test_dir = '/content/drive/MyDrive/Colab Skripsi/DATASETNEW/2_Split/test'


train_dir = r"D:\PROJECT\2_COMPUTER VISION\Image Segmentation\Data Train Gabungan"
val_dir = r"D:\PROJECT\2_COMPUTER VISION\Image Segmentation\Data Val Gabungan"
test_dir = r"D:\PROJECT\2_COMPUTER VISION\Image Segmentation\SPLIT\test"

# %%
train_generator = scale_datagen.flow_from_directory(
    train_dir,
    # subset='training',
    target_size=(224, 224),
    batch_size=40,
    class_mode='categorical'
)
# Out:
# Found 20412 images belonging to 4 classes.

# %%
val_generator = scale_datagen.flow_from_directory(
    val_dir,
    # subset='validation',
    target_size=(224, 224),
    batch_size=40,
    class_mode='categorical'
)
# Out:
# Found 5823 images belonging to 4 classes.

# %%
test_generator = scale_datagen.flow_from_directory(
    test_dir,
    # subset='validation',
    target_size=(224, 224),
    batch_size=40,
    class_mode='categorical'
)
# Out:
# Found 327 images belonging to 4 classes.

# %%
print(len(train_generator))
print(len(val_generator))
print(len(test_generator))
# Out:
# 511
# 146
# 9

# %%
# jadi ini modelnya kek gausah bikin dari nol lagi tapi pake arsitektur yang udah ada

from keras.applications import vgg16
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten, GlobalAveragePooling2D
from keras.layers import Conv2D, MaxPooling2D, ZeroPadding2D

from keras.models import Model

# SET DIMENSI INPUTNYA
img_rows, img_cols = 224, 224

# model learningnya based on imagenet dataset jadi weightnya set ke imagenet
# top layer diganti soalnya outputnya ada 20k neuron, tapi kita cuma butuh 2 neuron soalnya outputnya kan cuma 2, yes sama no
# ini download model yang udah ada jadi pake model vgg16
vgg = vgg16.VGG16(weights = "imagenet",
                  include_top = False,
                  input_shape = (img_rows, img_cols, 3))

# Ngefreeze 4 layer terkahir
# Layers yang di set ke trainable defaultnya True

for layer in vgg.layers:
  layer.trainable = False

# ngeprint semua layernya
for (i, layer) in enumerate(vgg.layers):
  print(str(i) + " "+ layer.__class__.__name__, layer.trainable)
# Out:
# 0 InputLayer False
# 1 Conv2D False
# 2 Conv2D False
# 3 MaxPooling2D False
# 4 Conv2D False
# 5 Conv2D False
# 6 MaxPooling2D False
# 7 Conv2D False
# 8 Conv2D False
# 9 Conv2D False
# 10 MaxPooling2D False
# 11 Conv2D False
# 12 Conv2D False
# 13 Conv2D False
# 14 MaxPooling2D False
# 15 Conv2D False
# 16 Conv2D False
# 17 Conv2D False
# 18 MaxPooling2D False

# %%
# tambahin beberapa layer ke model itu tadi

def lw(bottom_model, num_classes):
  """"creates the top or head of the model that will be
  placed ontop of the bottom layers"""

  top_model = bottom_model.output
  top_model = GlobalAveragePooling2D()(top_model)
  top_model = Dense(1024,activation="relu")(top_model)
  top_model = Dense(1024,activation="relu")(top_model)
  top_model = Dense(512,activation="relu")(top_model)
  top_model = Dense(num_classes,activation='softmax')(top_model) #last output layer, number of classes = 4
  return top_model

# %%
# itu tadi udah dibikin function lw nya, secara function lwnya di call

# jumlah class nya 2 soalnya yes sama no
num_classes = 4

FC_Head = lw(vgg, num_classes)

model = Model(inputs = vgg.input, outputs = FC_Head)

print(model.summary())
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 1024)              525312
#
#  dense_1 (Dense)             (None, 1024)              1049600
#
#  dense_2 (Dense)             (None, 512)               524800
#
#  dense_3 (Dense)             (None, 4)                 2052
#
# =================================================================
# Total params: 16,816,452
# Trainable params: 2,101,764
# Non-trainable params: 14,714,688
# _________________________________________________________________
# None

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
# model.compile(optimizer='adam', loss = 'categorical_crossentropy',metrics = ['accuracy'])


learning_rate = 0.0005
optimizer = Adam(learning_rate=learning_rate)

model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# training mulai
filepath=r'D:\PROJECT\SKRIPSI\skripsi_vgg16_0005_augment_1.model.keras'
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_accuracy',
                             save_best_only=True,
                             mode='max',
                             verbose=1)
history = model.fit(train_generator,
                    epochs=30,
                    validation_data=(val_generator),
                    initial_epoch=0,
                    callbacks=[checkpoint])


# # training mulai

# history = model.fit(train_generator,
#                     epochs=10,
#                     validation_data=(val_generator),
#                     verbose = 1,
#                     initial_epoch=0)
# Out:
# Epoch 1/30
# 511/511 [==============================] - ETA: 0s - loss: 0.5068 - accuracy: 0.7955
# Epoch 1: val_accuracy improved from -inf to 0.87275, saving model to D:\PROJECT\SKRIPSI\skripsi_vgg16_0005_augment_1.model.keras
# 511/511 [==============================] - 808s 2s/step - loss: 0.5068 - accuracy: 0.7955 - val_loss: 0.3170 - val_accuracy: 0.8727
# Epoch 2/30
# 511/511 [==============================] - ETA: 0s - loss: 0.2915 - accuracy: 0.8852
# Epoch 2: val_accuracy improved from 0.87275 to 0.91516, saving model to D:\PROJECT\SKRIPSI\skripsi_vgg16_0005_augment_1.model.keras
# 511/511 [==============================] - 266s 521ms/step - loss: 0.2915 - accuracy: 0.8852 - val_loss: 0.2358 - val_accuracy: 0.9152
# Epoch 3/30
# 511/511 [==============================] - ETA: 0s - loss: 0.2508 - accuracy: 0.9019
# Epoch 3: val_accuracy did not improve from 0.91516
# 511/511 [==============================] - 214s 419ms/step - loss: 0.2508 - accuracy: 0.9019 - val_loss: 0.2925 - val_accuracy: 0.8934
# Epoch 4/30
# 511/511 [==============================] - ETA: 0s - loss: 0.2321 - accuracy: 0.9075
# Epoch 4: val_accuracy did not improve from 0.91516
# 511/511 [==============================] - 205s 401ms/step - loss: 0.2321 - accuracy: 0.9075 - val_loss: 0.3039 - val_accuracy: 0.8870
# Epoch 5/30
# 511/511 [==============================] - ETA: 0s - loss: 0.2054 - accuracy: 0.9179
# Epoch 5: val_accuracy improved from 0.91516 to 0.92409, saving model to D:\PROJECT\SKRIPSI\skripsi_vgg16_0005_augment_1.model.keras
# 511/511 [==============================] - 206s 404ms/step - loss: 0.2054 - accuracy: 0.9179 - val_loss: 0.1981 - val_accuracy: 0.9241
# Epoch 6/30
# 511/511 [==============================] - ETA: 0s - loss: 0.1800 - accuracy: 0.9305
# Epoch 6: val_accuracy did not improve from 0.92409
# 511/511 [==============================] - 204s 400ms/step - loss: 0.1800 - accuracy: 0.9305 - val_loss: 0.2339 - val_accuracy: 0.9141
# Epoch 7/30
# 511/511 [==============================] - ETA: 0s - loss: 0.1683 - accuracy: 0.9323
# Epoch 7: val_accuracy did not improve from 0.92409
# 511/511 [==============================] - 198s 388ms/step - loss: 0.1683 - accuracy: 0.9323 - val_loss: 0.2046 - val_accuracy: 0.9222
# Epoch 8/30
# 511/511 [==============================] - ETA: 0s - loss: 0.1610 - accuracy: 0.9369
# Epoch 8: val_accuracy did not improve from 0.92409
# 511/511 [==============================] - 188s 369ms/step - loss: 0.1610 - accuracy: 0.9369 - val_loss: 0.2175 - val_accuracy: 0.9196
# Epoch 9/30
# 511/511 [==============================] - ETA: 0s - loss: 0.1461 - accuracy: 0.9427
# Epoch 9: val_accuracy did not improve from 0.92409
# 511/511 [==============================] - 165s 323ms/step - loss: 0.1461 - accuracy: 0.9427 - val_loss: 0.2671 - val_accuracy: 0.9165
# Epoch 10/30
# 511/511 [==============================] - ETA: 0s - loss: 0.1401 - accuracy: 0.9450
# Epoch 10: val_accuracy improved from 0.92409 to 0.92564, saving model to D:\PROJECT\SKRIPSI\skripsi_vgg16_0005_augment_1.model.keras
# 511/511 [==============================] - 164s 321ms/step - loss: 0.1401 - accuracy: 0.9450 - val_loss: 0.2066 - val_accuracy: 0.9256
# Epoch 11/30
# 511/511 [==============================] - ETA: 0s - loss: 0.1349 - accuracy: 0.9468
# Epoch 11: val_accuracy did not improve from 0.92564
# 511/511 [==============================] - 163s 319ms/step - loss: 0.1349 - accuracy: 0.9468 - val_loss: 0.2094 - val_accuracy: 0.9215
# Epoch 12/30
# 511/511 [==============================] - ETA: 0s - loss: 0.1294 - accuracy: 0.9508
# Epoch 12: val_accuracy improved from 0.92564 to 0.92615, saving model to D:\PROJECT\SKRIPSI\skripsi_vgg16_0005_augment_1.model.keras
# 511/511 [==============================] - 164s 321ms/step - loss: 0.1294 - accuracy: 0.9508 - val_loss: 0.2024 - val_accuracy: 0.9262
# Epoch 13/30
# 511/511 [==============================] - ETA: 0s - loss: 0.1342 - accuracy: 0.9469
# Epoch 13: val_accuracy improved from 0.92615 to 0.92736, saving model to D:\PROJECT\SKRIPSI\skripsi_vgg16_0005_augment_1.model.keras
# 511/511 [==============================] - 164s 322ms/step - loss: 0.1342 - accuracy: 0.9469 - val_loss: 0.2063 - val_accuracy: 0.9274
# Epoch 14/30
# 511/511 [==============================] - ETA: 0s - loss: 0.1179 - accuracy: 0.9525
# Epoch 14: val_accuracy did not improve from 0.92736
# 511/511 [==============================] - 164s 320ms/step - loss: 0.1179 - accuracy: 0.9525 - val_loss: 0.2254 - val_accuracy: 0.9220
# Epoch 15/30
# 511/511 [==============================] - ETA: 0s - loss: 0.1152 - accuracy: 0.9543
# Epoch 15: val_accuracy improved from 0.92736 to 0.93337, saving model to D:\PROJECT\SKRIPSI\skripsi_vgg16_0005_augment_1.model.keras
# 511/511 [==============================] - 163s 320ms/step - loss: 0.1152 - accuracy: 0.9543 - val_loss: 0.1874 - val_accuracy: 0.9334
# Epoch 16/30
# 511/511 [==============================] - ETA: 0s - loss: 0.1058 - accuracy: 0.9590
# Epoch 16: val_accuracy improved from 0.93337 to 0.93594, saving model to D:\PROJECT\SKRIPSI\skripsi_vgg16_0005_augment_1.model.keras
# 511/511 [==============================] - 164s 322ms/step - loss: 0.1058 - accuracy: 0.9590 - val_loss: 0.1922 - val_accuracy: 0.9359
# Epoch 17/30
# 511/511 [==============================] - ETA: 0s - loss: 0.1126 - accuracy: 0.9574
# Epoch 17: val_accuracy improved from 0.93594 to 0.93732, saving model to D:\PROJECT\SKRIPSI\skripsi_vgg16_0005_augment_1.model.keras
# 511/511 [==============================] - 165s 323ms/step - loss: 0.1126 - accuracy: 0.9574 - val_loss: 0.2057 - val_accuracy: 0.9373
# Epoch 18/30
# 511/511 [==============================] - ETA: 0s - loss: 0.1106 - accuracy: 0.9579
# Epoch 18: val_accuracy did not improve from 0.93732
# 511/511 [==============================] - 164s 320ms/step - loss: 0.1106 - accuracy: 0.9579 - val_loss: 0.2223 - val_accuracy: 0.9275
# Epoch 19/30
# 511/511 [==============================] - ETA: 0s - loss: 0.0975 - accuracy: 0.9618
# Epoch 19: val_accuracy did not improve from 0.93732
# 511/511 [==============================] - 164s 320ms/step - loss: 0.0975 - accuracy: 0.9618 - val_loss: 0.2724 - val_accuracy: 0.9184
# Epoch 20/30
# 511/511 [==============================] - ETA: 0s - loss: 0.0921 - accuracy: 0.9650
# Epoch 20: val_accuracy did not improve from 0.93732
# 511/511 [==============================] - 164s 321ms/step - loss: 0.0921 - accuracy: 0.9650 - val_loss: 0.2372 - val_accuracy: 0.9225
# Epoch 21/30
# 511/511 [==============================] - ETA: 0s - loss: 0.0943 - accuracy: 0.9639
# Epoch 21: val_accuracy did not improve from 0.93732
# 511/511 [==============================] - 163s 319ms/step - loss: 0.0943 - accuracy: 0.9639 - val_loss: 0.1976 - val_accuracy: 0.9371
# Epoch 22/30
# 511/511 [==============================] - ETA: 0s - loss: 0.0947 - accuracy: 0.9633
# Epoch 22: val_accuracy did not improve from 0.93732
# 511/511 [==============================] - 164s 321ms/step - loss: 0.0947 - accuracy: 0.9633 - val_loss: 0.2176 - val_accuracy: 0.9313
# Epoch 23/30
# 511/511 [==============================] - ETA: 0s - loss: 0.0846 - accuracy: 0.9675
# Epoch 23: val_accuracy did not improve from 0.93732
# 511/511 [==============================] - 164s 320ms/step - loss: 0.0846 - accuracy: 0.9675 - val_loss: 0.2066 - val_accuracy: 0.9370
# Epoch 24/30
# 511/511 [==============================] - ETA: 0s - loss: 0.0913 - accuracy: 0.9666
# Epoch 24: val_accuracy did not improve from 0.93732
# 511/511 [==============================] - 163s 319ms/step - loss: 0.0913 - accuracy: 0.9666 - val_loss: 0.1994 - val_accuracy: 0.9332
# Epoch 25/30
# 511/511 [==============================] - ETA: 0s - loss: 0.0755 - accuracy: 0.9718
# Epoch 25: val_accuracy did not improve from 0.93732
# 511/511 [==============================] - 164s 320ms/step - loss: 0.0755 - accuracy: 0.9718 - val_loss: 0.2837 - val_accuracy: 0.9243
# Epoch 26/30
# 511/511 [==============================] - ETA: 0s - loss: 0.0775 - accuracy: 0.9701
# Epoch 26: val_accuracy did not improve from 0.93732
# 511/511 [==============================] - 164s 321ms/step - loss: 0.0775 - accuracy: 0.9701 - val_loss: 0.2475 - val_accuracy: 0.9315
# Epoch 27/30
# 511/511 [==============================] - ETA: 0s - loss: 0.0756 - accuracy: 0.9705
# Epoch 27: val_accuracy did not improve from 0.93732
# 511/511 [==============================] - 163s 320ms/step - loss: 0.0756 - accuracy: 0.9705 - val_loss: 0.2177 - val_accuracy: 0.9325
# Epoch 28/30
# 511/511 [==============================] - ETA: 0s - loss: 0.0822 - accuracy: 0.9681
# Epoch 28: val_accuracy did not improve from 0.93732
# 511/511 [==============================] - 163s 320ms/step - loss: 0.0822 - accuracy: 0.9681 - val_loss: 0.2089 - val_accuracy: 0.9327
# Epoch 29/30
# 511/511 [==============================] - ETA: 0s - loss: 0.0743 - accuracy: 0.9714
# Epoch 29: val_accuracy did not improve from 0.93732
# 511/511 [==============================] - 163s 320ms/step - loss: 0.0743 - accuracy: 0.9714 - val_loss: 0.2217 - val_accuracy: 0.9330
# Epoch 30/30
# 511/511 [==============================] - ETA: 0s - loss: 0.0691 - accuracy: 0.9731
# Epoch 30: val_accuracy did not improve from 0.93732
# 511/511 [==============================] - 164s 321ms/step - loss: 0.0691 - accuracy: 0.9731 - val_loss: 0.3097 - val_accuracy: 0.9183

# %%
# SAVE MODEL
save_path = r"D:\PROJECT\SKRIPSI\skripsi_vgg16_0005_augment_1.h5"
model.save(save_path)

# %%
# SAVE MODEL
weights_path = r"D:\PROJECT\SKRIPSI\skripsi_vgg16_0005_augment_1_weights.h5"
model.save_weights(weights_path)

# %% [markdown]
# EVALUASI

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='validation accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc=0)
plt.figure()

plt.show()

# %%
# Grafik plot value accuracy training sama validation
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(acc, 'r', label='Training Accuracy')
plt.plot(val_acc, 'b', label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# Grafik plot value loss training sama validation
plt.subplot(1, 2, 2)
plt.plot(loss, 'g', label='Training Loss')
plt.plot(val_loss, 'y', label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.show()

# %%
from tensorflow import keras

model = keras.models.load_model("skripsi_vgg16_0005_augment_1.h5")

# %%
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator

img_size = (224, 224)
batch_size = 40

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode="categorical",  # Change to 'categorical' if multi-class
    shuffle=False
)

true_labels = test_generator.classes
# Out:
# Found 327 images belonging to 4 classes.

# %%
pred_probs = model.predict(test_generator)

pred_labels = np.argmax(pred_probs, axis=1)
# Out:
# 9/9 [==============================] - 8s 897ms/step

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(true_labels, pred_labels)

print("Confusion Matrix:")
print(cm)
# Out:
# Confusion Matrix:
# [[96  2  0  1]
#  [ 0 95  0  1]
#  [ 3  1 75  1]
#  [ 4  1  0 47]]

# %%
from sklearn.metrics import classification_report, accuracy_score

class_labels = list(test_generator.class_indices.keys())
print("Classification Report:")
print(classification_report(true_labels, pred_labels, target_names=class_labels, digits=4))

# akurasi
accuracy = accuracy_score(true_labels, pred_labels)
print(f"Accuracy: {accuracy:.4f}")
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#    EarlyPreB     0.9320    0.9697    0.9505        99
#         PreB     0.9596    0.9896    0.9744        96
#         ProB     1.0000    0.9375    0.9677        80
#       benign     0.9400    0.9038    0.9216        52
#
#     accuracy                         0.9572       327
#    macro avg     0.9579    0.9502    0.9535       327
# weighted avg     0.9580    0.9572    0.9571       327
#
# Accuracy: 0.9572

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()
