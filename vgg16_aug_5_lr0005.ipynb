# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
tf.config.list_physical_devices('GPU')
tf.test.is_gpu_available()
# Out:
# WARNING:tensorflow:From C:\Users\LEGION\AppData\Local\Temp\ipykernel_1808\4051749838.py:2: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# True

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
import tensorflow as tf
from zipfile import ZipFile
import os,glob
import cv2
from tqdm.notebook import tqdm_notebook as tqdm
import numpy as np
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Convolution2D, Dropout, Dense,MaxPooling2D
from keras.layers import BatchNormalization
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from zipfile import ZipFile
import numpy as np
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import pandas as pd
from keras.callbacks import ModelCheckpoint

# %%
import sys
from PIL import Image
sys.modules['Image'] = Image

# %%
from PIL import Image
print(Image.__file__)
# Out:
# c:\Users\LEGION\anaconda3\envs\python310\lib\site-packages\PIL\Image.py

# %%
import Image
print(Image.__file__)
# Out:
# c:\Users\LEGION\anaconda3\envs\python310\lib\site-packages\PIL\Image.py

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# scale_datagen = ImageDataGenerator(rescale=1./255,
#                                    validation_split=0.3)

scale_datagen = ImageDataGenerator(rescale=1./255)

# %%
# train_dir = r"D:\PROJECT\2_COMPUTER VISION\Image Segmentation\Augmented"
# # train_dir = '/content/drive/MyDrive/Colab Skripsi/DATASETNEW/2_Augmented'
# # val_dir = '/content/drive/MyDrive/Colab Skripsi/DATASETNEW/2_Split/val'
# # test_dir = '/content/drive/MyDrive/Colab Skripsi/DATASETNEW/2_Split/test'


train_dir = r"D:\PROJECT\2_COMPUTER VISION\Image Segmentation\SPLIT_TRAINDATA\train"
val_dir = r"D:\PROJECT\2_COMPUTER VISION\Image Segmentation\SPLIT_TRAINDATA\val"
test_dir = r"D:\PROJECT\2_COMPUTER VISION\Image Segmentation\SPLIT_TRAINDATA\test"

# %%
train_generator = scale_datagen.flow_from_directory(
    train_dir,
    # subset='training',
    target_size=(224, 224),
    batch_size=40,
    class_mode='categorical'
)
# Out:
# Found 20422 images belonging to 4 classes.

# %%
val_generator = scale_datagen.flow_from_directory(
    val_dir,
    # subset='validation',
    target_size=(224, 224),
    batch_size=40,
    class_mode='categorical'
)
# Out:
# Found 5834 images belonging to 4 classes.

# %%
test_generator = scale_datagen.flow_from_directory(
    test_dir,
    # subset='validation',
    target_size=(224, 224),
    batch_size=40,
    class_mode='categorical'
)
# Out:
# Found 2922 images belonging to 4 classes.

# %%
print(len(train_generator))
print(len(val_generator))
print(len(test_generator))
# Out:
# 511
# 146
# 74

# %%
# jadi ini modelnya kek gausah bikin dari nol lagi tapi pake arsitektur yang udah ada

from keras.applications import vgg16
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten, GlobalAveragePooling2D
from keras.layers import Conv2D, MaxPooling2D, ZeroPadding2D

from keras.models import Model

# SET DIMENSI INPUTNYA
img_rows, img_cols = 224, 224

# model learningnya based on imagenet dataset jadi weightnya set ke imagenet
# top layer diganti soalnya outputnya ada 20k neuron, tapi kita cuma butuh 2 neuron soalnya outputnya kan cuma 2, yes sama no
# ini download model yang udah ada jadi pake model vgg16
vgg = vgg16.VGG16(weights = "imagenet",
                  include_top = False,
                  input_shape = (img_rows, img_cols, 3))

# Ngefreeze 4 layer terkahir
# Layers yang di set ke trainable defaultnya True

for layer in vgg.layers:
  layer.trainable = False

# ngeprint semua layernya
for (i, layer) in enumerate(vgg.layers):
  print(str(i) + " "+ layer.__class__.__name__, layer.trainable)
# Out:
# 0 InputLayer False
# 1 Conv2D False
# 2 Conv2D False
# 3 MaxPooling2D False
# 4 Conv2D False
# 5 Conv2D False
# 6 MaxPooling2D False
# 7 Conv2D False
# 8 Conv2D False
# 9 Conv2D False
# 10 MaxPooling2D False
# 11 Conv2D False
# 12 Conv2D False
# 13 Conv2D False
# 14 MaxPooling2D False
# 15 Conv2D False
# 16 Conv2D False
# 17 Conv2D False
# 18 MaxPooling2D False

# %%
# tambahin beberapa layer ke model itu tadi

def lw(bottom_model, num_classes):
  """"creates the top or head of the model that will be
  placed ontop of the bottom layers"""

  top_model = bottom_model.output
  top_model = GlobalAveragePooling2D()(top_model)
  top_model = Dense(1024,activation="relu")(top_model)
  top_model = Dense(1024,activation="relu")(top_model)
  top_model = Dense(512,activation="relu")(top_model)
  top_model = Dense(num_classes,activation='softmax')(top_model) #last output layer, number of classes = 4
  return top_model

# %%
# itu tadi udah dibikin function lw nya, secara function lwnya di call

# jumlah class nya 2 soalnya yes sama no
num_classes = 4

FC_Head = lw(vgg, num_classes)

model = Model(inputs = vgg.input, outputs = FC_Head)

print(model.summary())
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 1024)              525312
#
#  dense_1 (Dense)             (None, 1024)              1049600
#
#  dense_2 (Dense)             (None, 512)               524800
#
#  dense_3 (Dense)             (None, 4)                 2052
#
# =================================================================
# Total params: 16,816,452
# Trainable params: 2,101,764
# Non-trainable params: 14,714,688
# _________________________________________________________________
# None

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
# model.compile(optimizer='adam', loss = 'categorical_crossentropy',metrics = ['accuracy'])


learning_rate = 0.0005
optimizer = Adam(learning_rate=learning_rate)

model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# training mulai
filepath=r'D:\PROJECT\SKRIPSI\skripsi_vgg16_0005_augment_1.model.keras'
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_accuracy',
                             save_best_only=True,
                             mode='max',
                             verbose=1)
history = model.fit(train_generator,
                    epochs=20,
                    validation_data=(val_generator),
                    initial_epoch=0,
                    callbacks=[checkpoint])


# # training mulai

# history = model.fit(train_generator,
#                     epochs=10,
#                     validation_data=(val_generator),
#                     verbose = 1,
#                     initial_epoch=0)
# Out:
# Epoch 1/20
# 511/511 [==============================] - ETA: 0s - loss: 0.4994 - accuracy: 0.8024
# Epoch 1: val_accuracy improved from -inf to 0.75523, saving model to D:\PROJECT\SKRIPSI\skripsi_vgg16_0005_augment_1.model.keras
# 511/511 [==============================] - 937s 2s/step - loss: 0.4994 - accuracy: 0.8024 - val_loss: 0.5180 - val_accuracy: 0.7552
# Epoch 2/20
# 511/511 [==============================] - ETA: 0s - loss: 0.2997 - accuracy: 0.8841
# Epoch 2: val_accuracy improved from 0.75523 to 0.90401, saving model to D:\PROJECT\SKRIPSI\skripsi_vgg16_0005_augment_1.model.keras
# 511/511 [==============================] - 162s 316ms/step - loss: 0.2997 - accuracy: 0.8841 - val_loss: 0.2432 - val_accuracy: 0.9040
# Epoch 3/20
# 511/511 [==============================] - ETA: 0s - loss: 0.2398 - accuracy: 0.9079
# Epoch 3: val_accuracy improved from 0.90401 to 0.91001, saving model to D:\PROJECT\SKRIPSI\skripsi_vgg16_0005_augment_1.model.keras
# 511/511 [==============================] - 161s 315ms/step - loss: 0.2398 - accuracy: 0.9079 - val_loss: 0.2407 - val_accuracy: 0.9100
# Epoch 4/20
# 511/511 [==============================] - ETA: 0s - loss: 0.2242 - accuracy: 0.9147
# Epoch 4: val_accuracy improved from 0.91001 to 0.92544, saving model to D:\PROJECT\SKRIPSI\skripsi_vgg16_0005_augment_1.model.keras
# 511/511 [==============================] - 162s 316ms/step - loss: 0.2242 - accuracy: 0.9147 - val_loss: 0.1900 - val_accuracy: 0.9254
# Epoch 5/20
# 511/511 [==============================] - ETA: 0s - loss: 0.2069 - accuracy: 0.9198
# Epoch 5: val_accuracy improved from 0.92544 to 0.92732, saving model to D:\PROJECT\SKRIPSI\skripsi_vgg16_0005_augment_1.model.keras
# 511/511 [==============================] - 161s 316ms/step - loss: 0.2069 - accuracy: 0.9198 - val_loss: 0.1866 - val_accuracy: 0.9273
# Epoch 6/20
# 511/511 [==============================] - ETA: 0s - loss: 0.1856 - accuracy: 0.9300
# Epoch 6: val_accuracy improved from 0.92732 to 0.93366, saving model to D:\PROJECT\SKRIPSI\skripsi_vgg16_0005_augment_1.model.keras
# 511/511 [==============================] - 167s 327ms/step - loss: 0.1856 - accuracy: 0.9300 - val_loss: 0.1754 - val_accuracy: 0.9337
# Epoch 7/20
# 511/511 [==============================] - ETA: 0s - loss: 0.1746 - accuracy: 0.9338
# Epoch 7: val_accuracy did not improve from 0.93366
# 511/511 [==============================] - 173s 339ms/step - loss: 0.1746 - accuracy: 0.9338 - val_loss: 0.1766 - val_accuracy: 0.9326
# Epoch 8/20
# 511/511 [==============================] - ETA: 0s - loss: 0.1667 - accuracy: 0.9347
# Epoch 8: val_accuracy improved from 0.93366 to 0.93486, saving model to D:\PROJECT\SKRIPSI\skripsi_vgg16_0005_augment_1.model.keras
# 511/511 [==============================] - 170s 332ms/step - loss: 0.1667 - accuracy: 0.9347 - val_loss: 0.1695 - val_accuracy: 0.9349
# Epoch 9/20
# 511/511 [==============================] - ETA: 0s - loss: 0.1593 - accuracy: 0.9393
# Epoch 9: val_accuracy did not improve from 0.93486
# 511/511 [==============================] - 172s 336ms/step - loss: 0.1593 - accuracy: 0.9393 - val_loss: 0.1603 - val_accuracy: 0.9335
# Epoch 10/20
# 511/511 [==============================] - ETA: 0s - loss: 0.1525 - accuracy: 0.9419
# Epoch 10: val_accuracy improved from 0.93486 to 0.94206, saving model to D:\PROJECT\SKRIPSI\skripsi_vgg16_0005_augment_1.model.keras
# 511/511 [==============================] - 161s 316ms/step - loss: 0.1525 - accuracy: 0.9419 - val_loss: 0.1464 - val_accuracy: 0.9421
# Epoch 11/20
# 511/511 [==============================] - ETA: 0s - loss: 0.1482 - accuracy: 0.9427
# Epoch 11: val_accuracy did not improve from 0.94206
# 511/511 [==============================] - 161s 315ms/step - loss: 0.1482 - accuracy: 0.9427 - val_loss: 0.1615 - val_accuracy: 0.9361
# Epoch 12/20
# 511/511 [==============================] - ETA: 0s - loss: 0.1306 - accuracy: 0.9486
# Epoch 12: val_accuracy did not improve from 0.94206
# 511/511 [==============================] - 161s 315ms/step - loss: 0.1306 - accuracy: 0.9486 - val_loss: 0.1569 - val_accuracy: 0.9354
# Epoch 13/20
# 511/511 [==============================] - ETA: 0s - loss: 0.1393 - accuracy: 0.9449
# Epoch 13: val_accuracy improved from 0.94206 to 0.94566, saving model to D:\PROJECT\SKRIPSI\skripsi_vgg16_0005_augment_1.model.keras
# 511/511 [==============================] - 161s 316ms/step - loss: 0.1393 - accuracy: 0.9449 - val_loss: 0.1393 - val_accuracy: 0.9457
# Epoch 14/20
# 511/511 [==============================] - ETA: 0s - loss: 0.1280 - accuracy: 0.9512
# Epoch 14: val_accuracy improved from 0.94566 to 0.94909, saving model to D:\PROJECT\SKRIPSI\skripsi_vgg16_0005_augment_1.model.keras
# 511/511 [==============================] - 161s 316ms/step - loss: 0.1280 - accuracy: 0.9512 - val_loss: 0.1392 - val_accuracy: 0.9491
# Epoch 15/20
# 511/511 [==============================] - ETA: 0s - loss: 0.1247 - accuracy: 0.9516
# Epoch 15: val_accuracy did not improve from 0.94909
# 511/511 [==============================] - 161s 316ms/step - loss: 0.1247 - accuracy: 0.9516 - val_loss: 0.1605 - val_accuracy: 0.9397
# Epoch 16/20
# 511/511 [==============================] - ETA: 0s - loss: 0.1212 - accuracy: 0.9525
# Epoch 16: val_accuracy improved from 0.94909 to 0.95012, saving model to D:\PROJECT\SKRIPSI\skripsi_vgg16_0005_augment_1.model.keras
# 511/511 [==============================] - 162s 316ms/step - loss: 0.1212 - accuracy: 0.9525 - val_loss: 0.1300 - val_accuracy: 0.9501
# Epoch 17/20
# 511/511 [==============================] - ETA: 0s - loss: 0.1201 - accuracy: 0.9545
# Epoch 17: val_accuracy did not improve from 0.95012
# 511/511 [==============================] - 161s 316ms/step - loss: 0.1201 - accuracy: 0.9545 - val_loss: 0.3004 - val_accuracy: 0.8929
# Epoch 18/20
# 511/511 [==============================] - ETA: 0s - loss: 0.1088 - accuracy: 0.9582
# Epoch 18: val_accuracy improved from 0.95012 to 0.95046, saving model to D:\PROJECT\SKRIPSI\skripsi_vgg16_0005_augment_1.model.keras
# 511/511 [==============================] - 162s 317ms/step - loss: 0.1088 - accuracy: 0.9582 - val_loss: 0.1344 - val_accuracy: 0.9505
# Epoch 19/20
# 511/511 [==============================] - ETA: 0s - loss: 0.1085 - accuracy: 0.9583
# Epoch 19: val_accuracy improved from 0.95046 to 0.95081, saving model to D:\PROJECT\SKRIPSI\skripsi_vgg16_0005_augment_1.model.keras
# 511/511 [==============================] - 162s 317ms/step - loss: 0.1085 - accuracy: 0.9583 - val_loss: 0.1289 - val_accuracy: 0.9508
# Epoch 20/20
# 511/511 [==============================] - ETA: 0s - loss: 0.1074 - accuracy: 0.9589
# Epoch 20: val_accuracy did not improve from 0.95081
# 511/511 [==============================] - 162s 317ms/step - loss: 0.1074 - accuracy: 0.9589 - val_loss: 0.1462 - val_accuracy: 0.9463

# %%
# SAVE MODEL
save_path = r"D:\PROJECT\SKRIPSI\skripsi_vgg16_0005_augment_1.h5"
model.save(save_path)

# %%
# SAVE MODEL
weights_path = r"D:\PROJECT\SKRIPSI\skripsi_vgg16_0005_augment_1_weights.h5"
model.save_weights(weights_path)

# %% [markdown]
# EVALUASI

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='validation accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc=0)
plt.figure()

plt.show()

# %%
# Grafik plot value accuracy training sama validation
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(acc, 'r', label='Training Accuracy')
plt.plot(val_acc, 'b', label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# Grafik plot value loss training sama validation
plt.subplot(1, 2, 2)
plt.plot(loss, 'g', label='Training Loss')
plt.plot(val_loss, 'y', label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.show()

# %%
from tensorflow import keras

model = keras.models.load_model("skripsi_vgg16_0005_augment_1.h5")

# %%
test_dir = r"D:\PROJECT\2_COMPUTER VISION\Image Segmentation\SPLIT_TRAINDATA\test"

# %%
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator

img_size = (224, 224)
batch_size = 40

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode="categorical",  # Change to 'categorical' if multi-class
    shuffle=False
)

true_labels = test_generator.classes
# Out:
# Found 2922 images belonging to 4 classes.

# %%
pred_probs = model.predict(test_generator)

pred_labels = np.argmax(pred_probs, axis=1)
# Out:
# 74/74 [==============================] - 42s 570ms/step

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(true_labels, pred_labels)

print("Confusion Matrix:")
print(cm)
# Out:
# Confusion Matrix:
# [[816  24  18  24]
#  [ 13 836   9   2]
#  [  0   1 717   0]
#  [ 29   9  10 414]]

# %%
from sklearn.metrics import classification_report, accuracy_score

class_labels = list(test_generator.class_indices.keys())
print("Classification Report:")
print(classification_report(true_labels, pred_labels, target_names=class_labels, digits=4))

# akurasi
accuracy = accuracy_score(true_labels, pred_labels)
print(f"Accuracy: {accuracy:.4f}")
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#    EarlyPreB     0.9510    0.9252    0.9379       882
#         PreB     0.9609    0.9721    0.9665       860
#         ProB     0.9509    0.9986    0.9742       718
#       benign     0.9409    0.8961    0.9180       462
#
#     accuracy                         0.9524      2922
#    macro avg     0.9510    0.9480    0.9491      2922
# weighted avg     0.9523    0.9524    0.9521      2922
#
# Accuracy: 0.9524

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()
