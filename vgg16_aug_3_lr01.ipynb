# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
tf.config.list_physical_devices('GPU')
tf.test.is_gpu_available()
# Out:
# WARNING:tensorflow:From C:\Users\LEGION\AppData\Local\Temp\ipykernel_10388\4051749838.py:2: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# True

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
import tensorflow as tf
from zipfile import ZipFile
import os,glob
import cv2
from tqdm.notebook import tqdm_notebook as tqdm
import numpy as np
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Convolution2D, Dropout, Dense,MaxPooling2D
from keras.layers import BatchNormalization
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from zipfile import ZipFile
import numpy as np
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import pandas as pd
from keras.callbacks import ModelCheckpoint

# %%
import sys
from PIL import Image
sys.modules['Image'] = Image

# %%
from PIL import Image
print(Image.__file__)
# Out:
# c:\Users\LEGION\anaconda3\envs\python310\lib\site-packages\PIL\Image.py

# %%
import Image
print(Image.__file__)
# Out:
# c:\Users\LEGION\anaconda3\envs\python310\lib\site-packages\PIL\Image.py

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# scale_datagen = ImageDataGenerator(rescale=1./255,
#                                    validation_split=0.3)

scale_datagen = ImageDataGenerator(rescale=1./255)

# %%
# train_dir = r"D:\PROJECT\2_COMPUTER VISION\Image Segmentation\Augmented"
# # train_dir = '/content/drive/MyDrive/Colab Skripsi/DATASETNEW/2_Augmented'
# # val_dir = '/content/drive/MyDrive/Colab Skripsi/DATASETNEW/2_Split/val'
# # test_dir = '/content/drive/MyDrive/Colab Skripsi/DATASETNEW/2_Split/test'


train_dir = r"D:\PROJECT\2_COMPUTER VISION\Image Segmentation\Data Train Gabungan"
val_dir = r"D:\PROJECT\2_COMPUTER VISION\Image Segmentation\Data Val Gabungan"
test_dir = r"D:\PROJECT\2_COMPUTER VISION\Image Segmentation\SPLIT\test"

# %%
train_generator = scale_datagen.flow_from_directory(
    train_dir,
    # subset='training',
    target_size=(224, 224),
    batch_size=40,
    class_mode='categorical'
)
# Out:
# Found 20412 images belonging to 4 classes.

# %%
val_generator = scale_datagen.flow_from_directory(
    val_dir,
    # subset='validation',
    target_size=(224, 224),
    batch_size=40,
    class_mode='categorical'
)
# Out:
# Found 5823 images belonging to 4 classes.

# %%
test_generator = scale_datagen.flow_from_directory(
    test_dir,
    # subset='validation',
    target_size=(224, 224),
    batch_size=40,
    class_mode='categorical'
)
# Out:
# Found 327 images belonging to 4 classes.

# %%
print(len(train_generator))
print(len(val_generator))
print(len(test_generator))
# Out:
# 511
# 146
# 9

# %%
# jadi ini modelnya kek gausah bikin dari nol lagi tapi pake arsitektur yang udah ada

from keras.applications import vgg16
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten, GlobalAveragePooling2D
from keras.layers import Conv2D, MaxPooling2D, ZeroPadding2D

from keras.models import Model

# SET DIMENSI INPUTNYA
img_rows, img_cols = 224, 224

# model learningnya based on imagenet dataset jadi weightnya set ke imagenet
# top layer diganti soalnya outputnya ada 20k neuron, tapi kita cuma butuh 2 neuron soalnya outputnya kan cuma 2, yes sama no
# ini download model yang udah ada jadi pake model vgg16
vgg = vgg16.VGG16(weights = "imagenet",
                  include_top = False,
                  input_shape = (img_rows, img_cols, 3))

# Ngefreeze 4 layer terkahir
# Layers yang di set ke trainable defaultnya True

for layer in vgg.layers:
  layer.trainable = False

# ngeprint semua layernya
for (i, layer) in enumerate(vgg.layers):
  print(str(i) + " "+ layer.__class__.__name__, layer.trainable)
# Out:
# 0 InputLayer False
# 1 Conv2D False
# 2 Conv2D False
# 3 MaxPooling2D False
# 4 Conv2D False
# 5 Conv2D False
# 6 MaxPooling2D False
# 7 Conv2D False
# 8 Conv2D False
# 9 Conv2D False
# 10 MaxPooling2D False
# 11 Conv2D False
# 12 Conv2D False
# 13 Conv2D False
# 14 MaxPooling2D False
# 15 Conv2D False
# 16 Conv2D False
# 17 Conv2D False
# 18 MaxPooling2D False

# %%
# tambahin beberapa layer ke model itu tadi

def lw(bottom_model, num_classes):
  """"creates the top or head of the model that will be
  placed ontop of the bottom layers"""

  top_model = bottom_model.output
  top_model = GlobalAveragePooling2D()(top_model)
  top_model = Dense(1024,activation="relu")(top_model)
  top_model = Dense(1024,activation="relu")(top_model)
  top_model = Dense(512,activation="relu")(top_model)
  top_model = Dense(num_classes,activation='softmax')(top_model) #last output layer, number of classes = 4
  return top_model

# %%
# itu tadi udah dibikin function lw nya, secara function lwnya di call

# jumlah class nya 2 soalnya yes sama no
num_classes = 4

FC_Head = lw(vgg, num_classes)

model = Model(inputs = vgg.input, outputs = FC_Head)

print(model.summary())
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 1024)              525312
#
#  dense_1 (Dense)             (None, 1024)              1049600
#
#  dense_2 (Dense)             (None, 512)               524800
#
#  dense_3 (Dense)             (None, 4)                 2052
#
# =================================================================
# Total params: 16,816,452
# Trainable params: 2,101,764
# Non-trainable params: 14,714,688
# _________________________________________________________________
# None

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
# model.compile(optimizer='adam', loss = 'categorical_crossentropy',metrics = ['accuracy'])


learning_rate = 0.01
optimizer = Adam(learning_rate=learning_rate)

model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# training mulai
filepath=r'D:\PROJECT\SKRIPSI\skripsi_vgg16_01_augment_1.model.keras'
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_accuracy',
                             save_best_only=True,
                             mode='max',
                             verbose=1)
history = model.fit(train_generator,
                    epochs=30,
                    validation_data=(val_generator),
                    initial_epoch=0,
                    callbacks=[checkpoint])


# # training mulai

# history = model.fit(train_generator,
#                     epochs=10,
#                     validation_data=(val_generator),
#                     verbose = 1,
#                     initial_epoch=0)
# Out:
# Epoch 1/30
# 511/511 [==============================] - ETA: 0s - loss: 0.7065 - accuracy: 0.7444
# Epoch 1: val_accuracy improved from -inf to 0.83050, saving model to D:\PROJECT\SKRIPSI\skripsi_vgg16_01_augment_1.model.keras
# 511/511 [==============================] - 184s 345ms/step - loss: 0.7065 - accuracy: 0.7444 - val_loss: 0.4624 - val_accuracy: 0.8305
# Epoch 2/30
# 511/511 [==============================] - ETA: 0s - loss: 0.3627 - accuracy: 0.8570
# Epoch 2: val_accuracy improved from 0.83050 to 0.87962, saving model to D:\PROJECT\SKRIPSI\skripsi_vgg16_01_augment_1.model.keras
# 511/511 [==============================] - 165s 323ms/step - loss: 0.3627 - accuracy: 0.8570 - val_loss: 0.3166 - val_accuracy: 0.8796
# Epoch 3/30
# 511/511 [==============================] - ETA: 0s - loss: 0.3245 - accuracy: 0.8728
# Epoch 3: val_accuracy improved from 0.87962 to 0.90469, saving model to D:\PROJECT\SKRIPSI\skripsi_vgg16_01_augment_1.model.keras
# 511/511 [==============================] - 165s 323ms/step - loss: 0.3245 - accuracy: 0.8728 - val_loss: 0.2693 - val_accuracy: 0.9047
# Epoch 4/30
# 511/511 [==============================] - ETA: 0s - loss: 0.2839 - accuracy: 0.8897
# Epoch 4: val_accuracy improved from 0.90469 to 0.90589, saving model to D:\PROJECT\SKRIPSI\skripsi_vgg16_01_augment_1.model.keras
# 511/511 [==============================] - 165s 324ms/step - loss: 0.2839 - accuracy: 0.8897 - val_loss: 0.2549 - val_accuracy: 0.9059
# Epoch 5/30
# 511/511 [==============================] - ETA: 0s - loss: 0.2776 - accuracy: 0.8920
# Epoch 5: val_accuracy did not improve from 0.90589
# 511/511 [==============================] - 165s 323ms/step - loss: 0.2776 - accuracy: 0.8920 - val_loss: 0.2744 - val_accuracy: 0.8959
# Epoch 6/30
# 511/511 [==============================] - ETA: 0s - loss: 0.2478 - accuracy: 0.9037
# Epoch 6: val_accuracy improved from 0.90589 to 0.91654, saving model to D:\PROJECT\SKRIPSI\skripsi_vgg16_01_augment_1.model.keras
# 511/511 [==============================] - 168s 328ms/step - loss: 0.2478 - accuracy: 0.9037 - val_loss: 0.2305 - val_accuracy: 0.9165
# Epoch 7/30
# 511/511 [==============================] - ETA: 0s - loss: 0.2376 - accuracy: 0.9056
# Epoch 7: val_accuracy did not improve from 0.91654
# 511/511 [==============================] - 168s 329ms/step - loss: 0.2376 - accuracy: 0.9056 - val_loss: 0.2815 - val_accuracy: 0.9014
# Epoch 8/30
# 511/511 [==============================] - ETA: 0s - loss: 0.2386 - accuracy: 0.9074
# Epoch 8: val_accuracy did not improve from 0.91654
# 511/511 [==============================] - 168s 329ms/step - loss: 0.2386 - accuracy: 0.9074 - val_loss: 0.2403 - val_accuracy: 0.9081
# Epoch 9/30
# 511/511 [==============================] - ETA: 0s - loss: 0.2210 - accuracy: 0.9130
# Epoch 9: val_accuracy did not improve from 0.91654
# 511/511 [==============================] - 168s 328ms/step - loss: 0.2210 - accuracy: 0.9130 - val_loss: 0.2481 - val_accuracy: 0.9059
# Epoch 10/30
# 511/511 [==============================] - ETA: 0s - loss: 0.2426 - accuracy: 0.9078
# Epoch 10: val_accuracy did not improve from 0.91654
# 511/511 [==============================] - 169s 330ms/step - loss: 0.2426 - accuracy: 0.9078 - val_loss: 0.2362 - val_accuracy: 0.9114
# Epoch 11/30
# 511/511 [==============================] - ETA: 0s - loss: 0.2137 - accuracy: 0.9163
# Epoch 11: val_accuracy improved from 0.91654 to 0.91826, saving model to D:\PROJECT\SKRIPSI\skripsi_vgg16_01_augment_1.model.keras
# 511/511 [==============================] - 178s 348ms/step - loss: 0.2137 - accuracy: 0.9163 - val_loss: 0.2456 - val_accuracy: 0.9183
# Epoch 12/30
# 511/511 [==============================] - ETA: 0s - loss: 0.2144 - accuracy: 0.9179
# Epoch 12: val_accuracy did not improve from 0.91826
# 511/511 [==============================] - 174s 340ms/step - loss: 0.2144 - accuracy: 0.9179 - val_loss: 0.2380 - val_accuracy: 0.9162
# Epoch 13/30
# 511/511 [==============================] - ETA: 0s - loss: 0.2126 - accuracy: 0.9154
# Epoch 13: val_accuracy did not improve from 0.91826
# 511/511 [==============================] - 175s 343ms/step - loss: 0.2126 - accuracy: 0.9154 - val_loss: 0.2492 - val_accuracy: 0.9112
# Epoch 14/30
# 511/511 [==============================] - ETA: 0s - loss: 0.2082 - accuracy: 0.9192
# Epoch 14: val_accuracy did not improve from 0.91826
# 511/511 [==============================] - 176s 344ms/step - loss: 0.2082 - accuracy: 0.9192 - val_loss: 0.4138 - val_accuracy: 0.8679
# Epoch 15/30
# 511/511 [==============================] - ETA: 0s - loss: 0.2032 - accuracy: 0.9217
# Epoch 15: val_accuracy did not improve from 0.91826
# 511/511 [==============================] - 177s 346ms/step - loss: 0.2032 - accuracy: 0.9217 - val_loss: 0.2549 - val_accuracy: 0.9140
# Epoch 16/30
# 511/511 [==============================] - ETA: 0s - loss: 0.1973 - accuracy: 0.9248
# Epoch 16: val_accuracy did not improve from 0.91826
# 511/511 [==============================] - 175s 343ms/step - loss: 0.1973 - accuracy: 0.9248 - val_loss: 0.2646 - val_accuracy: 0.9040
# Epoch 17/30
# 511/511 [==============================] - ETA: 0s - loss: 0.1874 - accuracy: 0.9281
# Epoch 17: val_accuracy did not improve from 0.91826
# 511/511 [==============================] - 174s 341ms/step - loss: 0.1874 - accuracy: 0.9281 - val_loss: 0.4361 - val_accuracy: 0.8657
# Epoch 18/30
# 511/511 [==============================] - ETA: 0s - loss: 0.1953 - accuracy: 0.9270
# Epoch 18: val_accuracy improved from 0.91826 to 0.92444, saving model to D:\PROJECT\SKRIPSI\skripsi_vgg16_01_augment_1.model.keras
# 511/511 [==============================] - 177s 346ms/step - loss: 0.1953 - accuracy: 0.9270 - val_loss: 0.2185 - val_accuracy: 0.9244
# Epoch 19/30
# 511/511 [==============================] - ETA: 0s - loss: 0.1816 - accuracy: 0.9309
# Epoch 19: val_accuracy did not improve from 0.92444
# 511/511 [==============================] - 177s 347ms/step - loss: 0.1816 - accuracy: 0.9309 - val_loss: 0.3388 - val_accuracy: 0.8901
# Epoch 20/30
# 511/511 [==============================] - ETA: 0s - loss: 0.1744 - accuracy: 0.9336
# Epoch 20: val_accuracy did not improve from 0.92444
# 511/511 [==============================] - 178s 347ms/step - loss: 0.1744 - accuracy: 0.9336 - val_loss: 0.2348 - val_accuracy: 0.9100
# Epoch 21/30
# 511/511 [==============================] - ETA: 0s - loss: 0.1852 - accuracy: 0.9299
# Epoch 21: val_accuracy did not improve from 0.92444
# 511/511 [==============================] - 179s 350ms/step - loss: 0.1852 - accuracy: 0.9299 - val_loss: 0.2496 - val_accuracy: 0.9145
# Epoch 22/30
# 511/511 [==============================] - ETA: 0s - loss: 0.1802 - accuracy: 0.9305
# Epoch 22: val_accuracy did not improve from 0.92444
# 511/511 [==============================] - 179s 350ms/step - loss: 0.1802 - accuracy: 0.9305 - val_loss: 0.2126 - val_accuracy: 0.9200
# Epoch 23/30
# 511/511 [==============================] - ETA: 0s - loss: 0.1706 - accuracy: 0.9337
# Epoch 23: val_accuracy did not improve from 0.92444
# 511/511 [==============================] - 179s 349ms/step - loss: 0.1706 - accuracy: 0.9337 - val_loss: 0.2387 - val_accuracy: 0.9215
# Epoch 24/30
# 511/511 [==============================] - ETA: 0s - loss: 0.1689 - accuracy: 0.9351
# Epoch 24: val_accuracy did not improve from 0.92444
# 511/511 [==============================] - 178s 348ms/step - loss: 0.1689 - accuracy: 0.9351 - val_loss: 0.2464 - val_accuracy: 0.9128
# Epoch 25/30
# 511/511 [==============================] - ETA: 0s - loss: 0.1628 - accuracy: 0.9384
# Epoch 25: val_accuracy did not improve from 0.92444
# 511/511 [==============================] - 180s 352ms/step - loss: 0.1628 - accuracy: 0.9384 - val_loss: 0.2504 - val_accuracy: 0.9160
# Epoch 26/30
# 511/511 [==============================] - ETA: 0s - loss: 0.1587 - accuracy: 0.9390
# Epoch 26: val_accuracy did not improve from 0.92444
# 511/511 [==============================] - 179s 350ms/step - loss: 0.1587 - accuracy: 0.9390 - val_loss: 0.2235 - val_accuracy: 0.9231
# Epoch 27/30
# 511/511 [==============================] - ETA: 0s - loss: 0.1665 - accuracy: 0.9363
# Epoch 27: val_accuracy did not improve from 0.92444
# 511/511 [==============================] - 176s 344ms/step - loss: 0.1665 - accuracy: 0.9363 - val_loss: 0.2452 - val_accuracy: 0.9150
# Epoch 28/30
# 511/511 [==============================] - ETA: 0s - loss: 0.1686 - accuracy: 0.9345
# Epoch 28: val_accuracy improved from 0.92444 to 0.92478, saving model to D:\PROJECT\SKRIPSI\skripsi_vgg16_01_augment_1.model.keras
# 511/511 [==============================] - 172s 337ms/step - loss: 0.1686 - accuracy: 0.9345 - val_loss: 0.2077 - val_accuracy: 0.9248
# Epoch 29/30
# 511/511 [==============================] - ETA: 0s - loss: 0.1598 - accuracy: 0.9411
# Epoch 29: val_accuracy did not improve from 0.92478
# 511/511 [==============================] - 168s 328ms/step - loss: 0.1598 - accuracy: 0.9411 - val_loss: 0.2208 - val_accuracy: 0.9212
# Epoch 30/30
# 511/511 [==============================] - ETA: 0s - loss: 0.1627 - accuracy: 0.9392
# Epoch 30: val_accuracy did not improve from 0.92478
# 511/511 [==============================] - 168s 328ms/step - loss: 0.1627 - accuracy: 0.9392 - val_loss: 0.2220 - val_accuracy: 0.9212

# %%
# SAVE MODEL
save_path = r"D:\PROJECT\SKRIPSI\skripsi_vgg16_01_augment_1.h5"
model.save(save_path)

# %%
# SAVE MODEL
weights_path = r"D:\PROJECT\SKRIPSI\skripsi_vgg16_01_augment_1_weights.h5"
model.save_weights(weights_path)

# %% [markdown]
# EVALUASI

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='validation accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc=0)
plt.figure()

plt.show()

# %%
# Grafik plot value accuracy training sama validation
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(acc, 'r', label='Training Accuracy')
plt.plot(val_acc, 'b', label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# Grafik plot value loss training sama validation
plt.subplot(1, 2, 2)
plt.plot(loss, 'g', label='Training Loss')
plt.plot(val_loss, 'y', label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.show()

# %%
from tensorflow import keras

model = keras.models.load_model("skripsi_vgg16_01_augment_1.h5")

# %%
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator

img_size = (224, 224)
batch_size = 40

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode="categorical",  # Change to 'categorical' if multi-class
    shuffle=False
)

true_labels = test_generator.classes
# Out:
# Found 327 images belonging to 4 classes.

# %%
pred_probs = model.predict(test_generator)

pred_labels = np.argmax(pred_probs, axis=1)
# Out:
# 9/9 [==============================] - 4s 462ms/step

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(true_labels, pred_labels)

print("Confusion Matrix:")
print(cm)
# Out:
# Confusion Matrix:
# [[95  2  0  2]
#  [ 2 94  0  0]
#  [ 1  1 78  0]
#  [ 7  1  0 44]]

# %%
from sklearn.metrics import classification_report, accuracy_score

class_labels = list(test_generator.class_indices.keys())
print("Classification Report:")
print(classification_report(true_labels, pred_labels, target_names=class_labels, digits=4))

# akurasi
accuracy = accuracy_score(true_labels, pred_labels)
print(f"Accuracy: {accuracy:.4f}")
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#    EarlyPreB     0.9048    0.9596    0.9314        99
#         PreB     0.9592    0.9792    0.9691        96
#         ProB     1.0000    0.9750    0.9873        80
#       benign     0.9565    0.8462    0.8980        52
#
#     accuracy                         0.9511       327
#    macro avg     0.9551    0.9400    0.9464       327
# weighted avg     0.9523    0.9511    0.9508       327
#
# Accuracy: 0.9511

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()
